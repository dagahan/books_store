# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Test notebook with selecting data, validation and display.

# %%
from src.notebooks.data.example_data import *

# %%
await data_base.init_alchemy_engine()

await seed_data()
# Out:
# 2025-08-14 18:19:13.615 | INFO     | src.services.db.database:init_alchemy_engine:31 - Starting service..
# 2025-08-14 18:19:13.617 | CRITICAL | src.core.utils:load_env_var:91 - Cannot load env var named 'RUNNING_INSIDE_DOCKER'. returning None.
# 2025-08-14 18:19:13.624 | DEBUG    | src.services.db.database:init_alchemy_engine:42 - postgresql+asyncpg://user:pwd@0.0.0.0:5432/EyeMath_db
# 2025-08-14 18:19:13.643 | INFO     | src.services.db.database:init_alchemy_engine:61 - Connection with data base has been established!
# 2025-08-14 18:19:13.644 | INFO     | src.notebooks.data.example_data:seed_data:6 - Seeding 384 users...
# 2025-08-14 18:21:13.295 | INFO     | src.notebooks.data.example_data:seed_data:19 - 384 users created.
# 2025-08-14 18:21:13.296 | INFO     | src.notebooks.data.example_data:seed_data:22 - Seeding 70 authors...
# 2025-08-14 18:21:13.303 | INFO     | src.notebooks.data.example_data:seed_data:28 - 70 authors created.
# 2025-08-14 18:21:13.303 | INFO     | src.notebooks.data.example_data:seed_data:31 - Seeding 20 sellers...
# 2025-08-14 18:21:13.312 | INFO     | src.notebooks.data.example_data:seed_data:40 - 20 sellers created.
# 2025-08-14 18:21:13.312 | INFO     | src.notebooks.data.example_data:seed_data:43 - Seeding 40 warehouses...
# 2025-08-14 18:21:13.318 | INFO     | src.notebooks.data.example_data:seed_data:49 - 40 warehouses created.
# 2025-08-14 18:21:13.318 | INFO     | src.notebooks.data.example_data:seed_data:52 - Seeding 141 product types...
# 2025-08-14 18:21:13.371 | ERROR    | src.notebooks.data.example_data:seed_data:97 - Error seeding data: (sqlalchemy.dialects.postgresql.asyncpg.Error) <class 'asyncpg.exceptions.DataError'>: invalid input for query argument $8: datetime.datetime(2022, 11, 11, 11, 21, ... (can't subtract offset-naive and offset-aware datetimes)
# [SQL: INSERT INTO product_types (id, name, seller_id, available, cost, sale, author_id, date_publication) VALUES ($1::UUID, $2::VARCHAR, $3::UUID, $4::BOOLEAN, $5::NUMERIC(10, 2), $6::FLOAT, $7::UUID, $8::TIMESTAMP WITHOUT TIME ZONE), ($9::UUID, $10::VARCH ... 19313 characters truncated ... MP WITHOUT TIME ZONE) RETURNING product_types.created_at, product_types.updated_at, product_types.id]
# [parameters: (UUID('9cc3f264-0dd6-4c3c-9e43-5a9ce526a877'), 'Кофемашина', UUID('40c1ac27-8964-48f9-b83d-f72508254002'), True, Decimal('177.93'), 0.027540789724677217, UUID('c43f469e-aa83-4513-a28e-05c62a74140d'), datetime.datetime(2022, 11, 11, 11, 21, 13, 318873, tzinfo=datetime.timezone.utc), UUID('a461d0d9-8ef2-4613-9ba0-3c2cdc35a6f6'), 'Джинсы', UUID('40c1ac27-8964-48f9-b83d-f72508254002'), True, Decimal('419.66'), 0.26319524060170885, UUID('e30a0eac-25a2-4b86-8afa-46a6be4243a2'), datetime.datetime(2022, 12, 13, 11, 21, 13, 318919, tzinfo=datetime.timezone.utc), UUID('6056fec5-db51-49cf-9b43-0f87dcc4fd59'), 'Ноутбук', UUID('a87b7212-d2b5-4ac7-9346-0bab44a345fe'), True, Decimal('496.64'), 0.22826908792217598, UUID('48b0df66-027d-4a67-98cd-ddb09a5b159e'), datetime.datetime(2021, 12, 6, 11, 21, 13, 318935, tzinfo=datetime.timezone.utc), UUID('43e61a11-562a-42fd-bedb-826f6da91f8a'), 'Клавиатура', UUID('727c1a6d-57ec-4d98-97d7-fa7214a08423'), True, Decimal('93.09'), 0.25387156697802965, UUID('a80ff5ee-ba32-479b-93d6-21d1073cbeb6'), datetime.datetime(2022, 7, 2, 11, 21, 13, 318947, tzinfo=datetime.timezone.utc), UUID('924f1e48-e3f2-474b-b6b7-2c98715d9b03'), 'Колонки', UUID('5f277562-fdbf-4358-8ad5-c47e4ea0c4ff'), True, Decimal('303.25'), 0.1397371544964855, UUID('52a17fe9-cf4f-4012-9b8e-2cc9e3dcd950'), datetime.datetime(2024, 11, 4, 11, 21, 13, 318958, tzinfo=datetime.timezone.utc), UUID('9ab8c7af-3c7c-4eb2-8eab-abe3915e65f2'), 'Веб-камера', UUID('e23f447a-ea4e-4ad2-b2c5-1200a46f9b70'), True, Decimal('190.92'), 0.35255242081949373, UUID('c43f469e-aa83-4513-a28e-05c62a74140d'), datetime.datetime(2021, 8, 14, 11, 21, 13, 318968, tzinfo=datetime.timezone.utc), UUID('ab941ff2-cb10-4f13-8a50-a3af976877e4'), 'Конструктор' ... 1028 parameters truncated ... UUID('10994606-930e-4e04-a53b-e56c3e713332'), datetime.datetime(2022, 1, 18, 11, 21, 13, 320138, tzinfo=datetime.timezone.utc), UUID('e95d5a47-7c6e-4e1b-84b8-3ced65b75deb'), 'Саксофон', UUID('2b2ab6e9-5e98-4009-9322-77394a86412f'), True, Decimal('39.53'), 0.4257171343644037, UUID('37940b48-a553-4027-88d0-415f874eea71'), datetime.datetime(2022, 6, 9, 11, 21, 13, 320147, tzinfo=datetime.timezone.utc), UUID('ce0ee050-d4e2-4b40-911f-21a76a259ff8'), 'Кофемашина', UUID('0cb02329-4018-4b33-86b3-b80482af7a06'), True, Decimal('429.15'), 0.022443569055396795, UUID('e0468246-2f9e-4b62-9e99-da0ba8828154'), datetime.datetime(2021, 2, 2, 11, 21, 13, 320155, tzinfo=datetime.timezone.utc), UUID('359f5fab-7689-45b0-a798-0ae3d981f18c'), 'Кофемашина', UUID('0cb02329-4018-4b33-86b3-b80482af7a06'), True, Decimal('470.93'), 0.2674990602066825, UUID('dddeaf44-c394-4e63-8c39-2ee33bd43d1b'), datetime.datetime(2022, 8, 4, 11, 21, 13, 320164, tzinfo=datetime.timezone.utc), UUID('eb2c1a01-2f5d-413c-8edc-32253336b499'), 'Фотоаппарат', UUID('00d4694a-bc5b-4277-bf00-adadf7fd7e82'), True, Decimal('61.63'), 0.435141670402065, UUID('237d2a1a-9178-48fe-a64f-69278acf3ea2'), datetime.datetime(2022, 3, 26, 11, 21, 13, 320172, tzinfo=datetime.timezone.utc), UUID('578990d4-e217-46ff-abcc-d12a6c713096'), 'Клавиатура', UUID('00768016-13ca-4d6b-8c70-e4ca87df3700'), True, Decimal('357.82'), 0.17846494845936434, UUID('6c932ece-b495-47fd-bae3-e93d825e0ef4'), datetime.datetime(2022, 4, 19, 11, 21, 13, 320181, tzinfo=datetime.timezone.utc), UUID('981eaf91-4090-4bd4-9862-d42e69685e3b'), 'Мяч', UUID('9cda40cc-9914-4cb6-8e27-e62adc7d65ac'), True, Decimal('479.57'), 0.14894509773840064, UUID('a95af883-6b23-4e49-b9a5-cfa69cb09a8e'), datetime.datetime(2024, 6, 29, 11, 21, 13, 320189, tzinfo=datetime.timezone.utc))]
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
# 2025-08-14 18:21:13.375 | DEBUG    | src.notebooks.data.example_data:seed_data:99 - Traceback (most recent call last):
#   File "asyncpg/protocol/prepared_stmt.pyx", line 175, in asyncpg.protocol.protocol.PreparedStatementState._encode_bind_msg
#   File "asyncpg/protocol/codecs/base.pyx", line 227, in asyncpg.protocol.protocol.Codec.encode
#   File "asyncpg/protocol/codecs/base.pyx", line 129, in asyncpg.protocol.protocol.Codec.encode_scalar
#   File "asyncpg/pgproto/./codecs/datetime.pyx", line 152, in asyncpg.pgproto.pgproto.timestamp_encode
# TypeError: can't subtract offset-naive and offset-aware datetimes
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 545, in _prepare_and_execute
#     self._rows = deque(await prepared_stmt.fetch(*parameters))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/asyncpg/prepared_stmt.py", line 176, in fetch
#     data = await self.__bind_execute(args, 0, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/asyncpg/prepared_stmt.py", line 267, in __bind_execute
#     data, status, _ = await self.__do_execute(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^
#         lambda protocol: protocol.bind_execute(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             self._state, args, '', limit, True, timeout))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/asyncpg/prepared_stmt.py", line 256, in __do_execute
#     return await executor(protocol)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "asyncpg/protocol/protocol.pyx", line 185, in bind_execute
#   File "asyncpg/protocol/prepared_stmt.pyx", line 204, in asyncpg.protocol.protocol.PreparedStatementState._encode_bind_msg
# asyncpg.exceptions.DataError: invalid input for query argument $8: datetime.datetime(2022, 11, 11, 11, 21, ... (can't subtract offset-naive and offset-aware datetimes)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 2114, in _exec_insertmany_context
#     dialect.do_execute(
#     ~~~~~~~~~~~~~~~~~~^
#         cursor,
#         ^^^^^^^
#     ...<2 lines>...
#         context,
#         ^^^^^^^^
#     )
#     ^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py", line 943, in do_execute
#     cursor.execute(statement, parameters)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 580, in execute
#     self._adapt_connection.await_(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._prepare_and_execute(operation, parameters)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/util/_concurrency_py3k.py", line 132, in await_only
#     return current.parent.switch(awaitable)  # type: ignore[no-any-return,attr-defined] # noqa: E501
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/util/_concurrency_py3k.py", line 196, in greenlet_spawn
#     value = await result
#             ^^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 558, in _prepare_and_execute
#     self._handle_exception(error)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 508, in _handle_exception
#     self._adapt_connection._handle_exception(error)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 792, in _handle_exception
#     raise translated_error from error
# sqlalchemy.dialects.postgresql.asyncpg.AsyncAdapt_asyncpg_dbapi.Error: <class 'asyncpg.exceptions.DataError'>: invalid input for query argument $8: datetime.datetime(2022, 11, 11, 11, 21, ... (can't subtract offset-naive and offset-aware datetimes)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<string>", line 59, in seed_data
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/ext/asyncio/session.py", line 801, in flush
#     await greenlet_spawn(self.sync_session.flush, objects=objects)
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/util/_concurrency_py3k.py", line 203, in greenlet_spawn
#     result = context.switch(value)
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py", line 4345, in flush
#     self._flush(objects)
#     ~~~~~~~~~~~^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py", line 4480, in _flush
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py", line 4441, in _flush
#     flush_context.execute()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/orm/unitofwork.py", line 466, in execute
#     rec.execute(self)
#     ~~~~~~~~~~~^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/orm/unitofwork.py", line 642, in execute
#     util.preloaded.orm_persistence.save_obj(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self.mapper,
#         ^^^^^^^^^^^^
#         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         uow,
#         ^^^^
#     )
#     ^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/orm/persistence.py", line 93, in save_obj
#     _emit_insert_statements(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         base_mapper,
#         ^^^^^^^^^^^^
#     ...<3 lines>...
#         insert,
#         ^^^^^^^
#     )
#     ^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/orm/persistence.py", line 1143, in _emit_insert_statements
#     result = connection.execute(
#         statement, multiparams, execution_options=execution_options
#     )
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 1415, in execute
#     return meth(
#         self,
#         distilled_parameters,
#         execution_options or NO_OPTIONS,
#     )
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/sql/elements.py", line 523, in _execute_on_connection
#     return connection._execute_clauseelement(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self, distilled_params, execution_options
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 1637, in _execute_clauseelement
#     ret = self._execute_context(
#         dialect,
#     ...<8 lines>...
#         cache_hit=cache_hit,
#     )
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 1840, in _execute_context
#     return self._exec_insertmany_context(dialect, context)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 2122, in _exec_insertmany_context
#     self._handle_dbapi_exception(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         e,
#         ^^
#     ...<4 lines>...
#         is_sub_exec=True,
#         ^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 2351, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 2114, in _exec_insertmany_context
#     dialect.do_execute(
#     ~~~~~~~~~~~~~~~~~~^
#         cursor,
#         ^^^^^^^
#     ...<2 lines>...
#         context,
#         ^^^^^^^^
#     )
#     ^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py", line 943, in do_execute
#     cursor.execute(statement, parameters)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 580, in execute
#     self._adapt_connection.await_(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._prepare_and_execute(operation, parameters)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/util/_concurrency_py3k.py", line 132, in await_only
#     return current.parent.switch(awaitable)  # type: ignore[no-any-return,attr-defined] # noqa: E501
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/util/_concurrency_py3k.py", line 196, in greenlet_spawn
#     value = await result
#             ^^^^^^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 558, in _prepare_and_execute
#     self._handle_exception(error)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 508, in _handle_exception
#     self._adapt_connection._handle_exception(error)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "/home/usov/myprojects/books_store/db_manager/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py", line 792, in _handle_exception
#     raise translated_error from error
# sqlalchemy.exc.DBAPIError: (sqlalchemy.dialects.postgresql.asyncpg.Error) <class 'asyncpg.exceptions.DataError'>: invalid input for query argument $8: datetime.datetime(2022, 11, 11, 11, 21, ... (can't subtract offset-naive and offset-aware datetimes)
# [SQL: INSERT INTO product_types (id, name, seller_id, available, cost, sale, author_id, date_publication) VALUES ($1::UUID, $2::VARCHAR, $3::UUID, $4::BOOLEAN, $5::NUMERIC(10, 2), $6::FLOAT, $7::UUID, $8::TIMESTAMP WITHOUT TIME ZONE), ($9::UUID, $10::VARCH ... 19313 characters truncated ... MP WITHOUT TIME ZONE) RETURNING product_types.created_at, product_types.updated_at, product_types.id]
# [parameters: (UUID('9cc3f264-0dd6-4c3c-9e43-5a9ce526a877'), 'Кофемашина', UUID('40c1ac27-8964-48f9-b83d-f72508254002'), True, Decimal('177.93'), 0.027540789724677217, UUID('c43f469e-aa83-4513-a28e-05c62a74140d'), datetime.datetime(2022, 11, 11, 11, 21, 13, 318873, tzinfo=datetime.timezone.utc), UUID('a461d0d9-8ef2-4613-9ba0-3c2cdc35a6f6'), 'Джинсы', UUID('40c1ac27-8964-48f9-b83d-f72508254002'), True, Decimal('419.66'), 0.26319524060170885, UUID('e30a0eac-25a2-4b86-8afa-46a6be4243a2'), datetime.datetime(2022, 12, 13, 11, 21, 13, 318919, tzinfo=datetime.timezone.utc), UUID('6056fec5-db51-49cf-9b43-0f87dcc4fd59'), 'Ноутбук', UUID('a87b7212-d2b5-4ac7-9346-0bab44a345fe'), True, Decimal('496.64'), 0.22826908792217598, UUID('48b0df66-027d-4a67-98cd-ddb09a5b159e'), datetime.datetime(2021, 12, 6, 11, 21, 13, 318935, tzinfo=datetime.timezone.utc), UUID('43e61a11-562a-42fd-bedb-826f6da91f8a'), 'Клавиатура', UUID('727c1a6d-57ec-4d98-97d7-fa7214a08423'), True, Decimal('93.09'), 0.25387156697802965, UUID('a80ff5ee-ba32-479b-93d6-21d1073cbeb6'), datetime.datetime(2022, 7, 2, 11, 21, 13, 318947, tzinfo=datetime.timezone.utc), UUID('924f1e48-e3f2-474b-b6b7-2c98715d9b03'), 'Колонки', UUID('5f277562-fdbf-4358-8ad5-c47e4ea0c4ff'), True, Decimal('303.25'), 0.1397371544964855, UUID('52a17fe9-cf4f-4012-9b8e-2cc9e3dcd950'), datetime.datetime(2024, 11, 4, 11, 21, 13, 318958, tzinfo=datetime.timezone.utc), UUID('9ab8c7af-3c7c-4eb2-8eab-abe3915e65f2'), 'Веб-камера', UUID('e23f447a-ea4e-4ad2-b2c5-1200a46f9b70'), True, Decimal('190.92'), 0.35255242081949373, UUID('c43f469e-aa83-4513-a28e-05c62a74140d'), datetime.datetime(2021, 8, 14, 11, 21, 13, 318968, tzinfo=datetime.timezone.utc), UUID('ab941ff2-cb10-4f13-8a50-a3af976877e4'), 'Конструктор' ... 1028 parameters truncated ... UUID('10994606-930e-4e04-a53b-e56c3e713332'), datetime.datetime(2022, 1, 18, 11, 21, 13, 320138, tzinfo=datetime.timezone.utc), UUID('e95d5a47-7c6e-4e1b-84b8-3ced65b75deb'), 'Саксофон', UUID('2b2ab6e9-5e98-4009-9322-77394a86412f'), True, Decimal('39.53'), 0.4257171343644037, UUID('37940b48-a553-4027-88d0-415f874eea71'), datetime.datetime(2022, 6, 9, 11, 21, 13, 320147, tzinfo=datetime.timezone.utc), UUID('ce0ee050-d4e2-4b40-911f-21a76a259ff8'), 'Кофемашина', UUID('0cb02329-4018-4b33-86b3-b80482af7a06'), True, Decimal('429.15'), 0.022443569055396795, UUID('e0468246-2f9e-4b62-9e99-da0ba8828154'), datetime.datetime(2021, 2, 2, 11, 21, 13, 320155, tzinfo=datetime.timezone.utc), UUID('359f5fab-7689-45b0-a798-0ae3d981f18c'), 'Кофемашина', UUID('0cb02329-4018-4b33-86b3-b80482af7a06'), True, Decimal('470.93'), 0.2674990602066825, UUID('dddeaf44-c394-4e63-8c39-2ee33bd43d1b'), datetime.datetime(2022, 8, 4, 11, 21, 13, 320164, tzinfo=datetime.timezone.utc), UUID('eb2c1a01-2f5d-413c-8edc-32253336b499'), 'Фотоаппарат', UUID('00d4694a-bc5b-4277-bf00-adadf7fd7e82'), True, Decimal('61.63'), 0.435141670402065, UUID('237d2a1a-9178-48fe-a64f-69278acf3ea2'), datetime.datetime(2022, 3, 26, 11, 21, 13, 320172, tzinfo=datetime.timezone.utc), UUID('578990d4-e217-46ff-abcc-d12a6c713096'), 'Клавиатура', UUID('00768016-13ca-4d6b-8c70-e4ca87df3700'), True, Decimal('357.82'), 0.17846494845936434, UUID('6c932ece-b495-47fd-bae3-e93d825e0ef4'), datetime.datetime(2022, 4, 19, 11, 21, 13, 320181, tzinfo=datetime.timezone.utc), UUID('981eaf91-4090-4bd4-9862-d42e69685e3b'), 'Мяч', UUID('9cda40cc-9914-4cb6-8e27-e62adc7d65ac'), True, Decimal('479.57'), 0.14894509773840064, UUID('a95af883-6b23-4e49-b9a5-cfa69cb09a8e'), datetime.datetime(2024, 6, 29, 11, 21, 13, 320189, tzinfo=datetime.timezone.utc))]
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
